# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup 

my_url = 'https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&DEPA=0&Order=BESTMATCH&Description=graphics+card&N=-1&isNodeId=1'

uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

#html parsing

page_soup = soup(page_html,"html.parser")

#grabs each product

containers = page_soup.findAll("div",{"class":"item-container"})

#creating and writing into a file

filename = "product.csv"

f = open(filename,"w")

headers = "brand, product_name, shipping \n"

f.write(headers)
i=1

for container in containers:
	brand = container.div.div.a.img["title"]

	title_container = container.findAll("a",{"class":"item-title"})
	product_name = title_container[0].text

	shipping_container = container.findAll("li",{"class":"price-ship"})
	shipping = shipping_container[0].text.strip()

	print("\n product :",i)
	i=i+1

	print("brand : "+brand)
	print("product_name : "+product_name)
	print("shipping : "+shipping)


   
	f.write(brand+ "," +product_name.replace(",","|")+ "," +shipping+ "\n")

f.close()
# Out:
#  product : 1
# brand : Sapphire Tech
# product_name : Sapphire Radeon NITRO+ RX 580 4GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)
# shipping :
#
#  product : 2
# brand : MSI
# product_name : MSI GeForce GTX 1050 Ti DirectX 12 GTX 1050 Ti 4G OC 4GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 3
# brand : MSI
# product_name : MSI GeForce GTX 1060 DirectX 12 GTX 1060 AERO ITX 3G OC 3GB 192-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 4
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GT 1030 2GB (VCGGT10302PB)
# shipping :
#
#  product : 5
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1050 Ti DirectX 12 ZT-P10510A-10L 4GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 6
# brand : GIGABYTE
# product_name : GIGABYTE HD Experience Series GeForce 210 DirectX 10.1 GV-N210SL-1GI 1GB 64-Bit DDR3 PCI Express 2.0 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 7
# brand : GIGABYTE
# product_name : GIGABYTE Ultra Durable 2 Series GeForce GT 730 DirectX 12 GV-N730-2GI (rev. 1.0) 2GB 128-Bit DDR3 PCI Express 2.0 HDCP Ready ATX Video Card
# shipping :
#
#  product : 8
# brand : EVGA
# product_name : EVGA GeForce GT 730 DirectX 12 01G-P3-3730-KR 1GB 64-Bit GDDR5 PCI Express 2.0 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 9
# brand : GIGABYTE
# product_name : GIGABYTE Radeon RX 470 DirectX 12 GV-RX470G1 GAMING-4G 4GB 256-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 10
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 1080 DirectX 12 VCGGTX10808XGPB-OC 8GB 256-Bit GDDR5X PCI Express 3.0 x16 SLI Support XLR8 Gaming OC Edition Video Card
# shipping :
#
#  product : 11
# brand : ASUS
# product_name : ASUS ROG Strix Radeon RX 560 O4GB Gaming OC Edition GDDR5 DP HDMI DVI AMD Graphics Card (ROG-STRIX-RX560-O4G-GAMING)
# shipping :
#
#  product : 12
# brand : ASUS
# product_name : Asus R5230-SL-2GD3-L Radeon R5 230 Graphic Card - 650 MHz Core - 2 GB DDR3 SDRAM - PCI Express 2.1 - Low-profile
# shipping :
#
#  product : 13
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping :
#
#  product : 14
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1080 Ti DirectX 12 GV-N108TGAMINGOC BLACK-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 15
# brand : MSI
# product_name : MSI Radeon RX 550 DirectX 12 RX 550 2GT LP OC 2GB 128-Bit GDDR5 PCI Express x16 (uses x8) HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 16
# brand : EVGA
# product_name : EVGA 200 GeForce 210 DirectX 10.1 01G-P3-1312-LR 1GB 64-Bit DDR3 PCI Express 2.0 x16 HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 17
# brand : EVGA
# product_name : EVGA GeForce 210 DirectX 10.1 512-P3-1310-LR 512MB 32-Bit DDR3 PCI Express 2.0 x16 HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 18
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1070 DirectX 12 GV-N1070WF2OC-8GD 8GB 256-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 19
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1070 DirectX 12 GV-N1070G1 GAMING-8GD R2 256-Bit GDDR5 PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping :
#
#  product : 20
# brand : MSI
# product_name : MSI Radeon R7 250 DirectX 12 R7 250 2GD3 OC 2GB 128-Bit DDR3 PCI Express 3.0 HDCP Ready CrossFireX Support Video Card
# shipping :
#
#  product : 21
# brand : GIGABYTE
# product_name : GIGABYTE AORUS Xtreme GeForce GTX 1080 Ti Waterforce 11GD
# shipping :
#
#  product : 22
# brand : EVGA
# product_name : EVGA GeForce GT 710 DirectX 12 02G-P3-2712-KR 2GB 64-Bit DDR3 PCI Express 2.0 Video Card
# shipping :
#
#  product : 23
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 FTW2 GAMING iCX, 08G-P4-6676-KR, 8GB GDDR5, RGB LED, 9 Thermal Sensors, Asynchronous Fan Control, Thermal Display LED System, Optimized Airflow Fin Design
# shipping :
#
#  product : 24
# brand : Lenovo
# product_name : Lenovo 4X60M28228 Nvidia Quadro M2000 - Graphics Card - Quadro M2000 - 4 Gb - 4 X Displayport - For Thinkstation P410, P510
# shipping :
#
#  product : 25
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 1060 DirectX 12 VCGGTX10603PB 3GB 192-Bit GDDR5 PCI Express 3.0 x16 Video Card
# shipping :
#
#  product : 26
# brand : ZOTAC
# product_name : ZOTAC GeForce GT 730 DirectX 12 (feature level 11_0) ZT-71113-20L 2GB 64-Bit DDR3 PCI Express 2.0 x16 (x8 lanes) HDCP Ready Zone Edition Video Card
# shipping :
#
#  product : 27
# brand : ZOTAC
# product_name : ZOTAC GeForce GT 730 DirectX 12 ZT-71118-10L 4GB 64-Bit DDR5 PCI Express 2.0 x 8 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 28
# brand : XFX
# product_name : XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card
# shipping :
#
#  product : 29
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS X-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 ATX Xtreme Edition Video Card
# shipping :
#
#  product : 30
# brand : ASUS
# product_name : ASUS GeForce GTX 1060 STRIX-GTX1060-6G-GAMING 6GB 192-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 31
# brand : MSI
# product_name : MSI Black Radeon RX Vega 64 DirectX 12 RADEON RX VEGA 64 8G 8GB 2048-Bit HBM2 PCI Express 3.0 x16 HDCP Ready CrossFireX Support Video Card - Black Fan
# shipping :
#
#  product : 32
# brand : MSI
# product_name : MSI GeForce GTX 1050 DirectX 12 GTX 1050 AERO ITX 2G OC 2GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 33
# brand : MSI
# product_name : MSI GeForce GTX 1080 Ti DirectX 12 GTX 1080 Ti LIGHTNING X 11GB 352-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# shipping :
#
#  product : 34
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1050 DirectX 12 ZT-P10500A-10L 2GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 35
# brand : MSI
# product_name : MSI GeForce GT 730 DirectX 12 N730-2GD3V3 2GB 128-Bit DDR3 PCI Express 2.0 x16 HDCP Ready ATX Video Card
# shipping :
#
#  product : 36
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)
# shipping :

# %%
container.prettify()
# Out:
# '<div class="item-container ">\n <!--product image-->\n <a class="item-img" href="https://www.newegg.com/global/in/Product/Product.aspx?Item=N82E16814487265&amp;cm_re=graphics_card-_-14-487-265-_-Product">\n  <img alt="EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)" src="//images10.newegg.com/ProductImageCompressAll300/14-487-265-S99.jpg" title="EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)"/>\n </a>\n <div class="item-info">\n  <!--brand info-->\n  <div class="item-branding">\n   <a class="item-brand" href="https://www.newegg.com/global/in/EVGA/BrandStore/ID-1402">\n    <img alt="EVGA" src="//images10.newegg.com/Brandimage_70x28//Brand1402.gif" title="EVGA"/>\n   </a>\n   <!--rating info-->\n   <a class="item-rating" href="https://www.newegg.com/global/in/Product/Product.aspx?Item=N82E16814487265&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;ignorebbr=1&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 4">\n    <i class="rating rating-4">\n    </i>\n    <span class="item-rating-num">\n     (145)\n    </span>\n   </a>\n  </div>\n  <!--description info-->\n  <a class="item-title" href="https://www.newegg.com/global/in/Product/Product.aspx?Item=N82E16814487265&amp;cm_re=graphics_card-_-14-487-265-_-Product" title="View Details">\n   EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)\n  </a>\n  <!--promption info-->\n  <p class="item-promo">\n   <i class="item-promo-icon">\n   </i>\n   Customer Choice Award Winner\n  </p>\n  <!--feature-->\n  <ul class="item-features">\n   <li>\n    <strong>\n     Core Clock:\n    </strong>\n    1594 MHz\n   </li>\n   <li>\n    <strong>\n     Max Resolution:\n    </strong>\n    7680 x 4320\n   </li>\n   <li>\n    <strong>\n     DisplayPort:\n    </strong>\n    3 x DisplayPort 1.4\n   </li>\n   <li>\n    <strong>\n     DVI:\n    </strong>\n    1 x Dual-Link DVI-D\n   </li>\n   <li>\n    <strong>\n     Model #:\n    </strong>\n    08G-P4-5173-KR\n   </li>\n   <li>\n    <strong>\n     Item #:\n    </strong>\n    N82E16814487265\n   </li>\n   <li>\n    <strong>\n     Return Policy:\n    </strong>\n    <a href="https://kb.newegg.com/Article/Index/12/3?id=1167#32074" target="_blank" title="International Order Return Policy(New Window)">\n     International Order Return Policy\n    </a>\n   </li>\n  </ul>\n  <div class="item-action">\n   <!--price-->\n   <ul class="price ">\n    <li class="price-was">\n    </li>\n    <li class="price-map">\n    </li>\n    <li class="price-current">\n     <span class="price-current-label">\n     </span>\n     ₹ 28,846\n     <span class="price-current-range">\n      <abbr title="to">\n       –\n      </abbr>\n     </span>\n    </li>\n    <li class="price-save">\n     <span class="price-save-endtime price-save-endtime-current">\n     </span>\n     <span class="price-save-endtime price-save-endtime-another" style="display:none;">\n     </span>\n    </li>\n    <li class="price-note">\n    </li>\n    <li class="price-ship">\n    </li>\n   </ul>\n   <!--egg point-->\n   <!--financing-->\n   <!--button-->\n   <div class="item-operate ">\n    <div class="item-button-area">\n     <button class="btn btn-mini btn-primary" onclick="Biz.Product.video.conversion(\'\',\'14-487-265\',\'1\');Javascript:Biz.ProductList.Item.add(\'https://secure.newegg.com/Shopping/AddToCart.aspx?Submit=ADD&amp;ItemList=N82E16814487265\');" title="Add EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC) to cart" type="button">\n      Add To Cart\n      <i class="fa fa-caret-right">\n      </i>\n     </button>\n    </div>\n    <!--compare-->\n    <div class="item-compare-box">\n     <label class="form-checkbox">\n      <input autocomplete="off" id="CompareItem_14-487-265" name="CompareItem" neg-itemnumber=" ...
