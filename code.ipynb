# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup 

my_url = 'https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&DEPA=0&Order=BESTMATCH&Description=graphics+card&N=-1&isNodeId=1'

uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

#html parsing

page_soup = soup(page_html,"html.parser")

#grabs each product

containers = page_soup.findAll("div",{"class":"item-container"})

#creating and writing into a file

filename = "product.csv"

f = open(filename,"w")

headers = "brand, product_name, shipping \n"

f.write(headers)
i=1

for container in containers:
	brand = container.div.div.a.img["title"]

	title_container = container.findAll("a",{"class":"item-title"})
	product_name = title_container[0].text

	shipping_container = container.findAll("li",{"class":"price-ship"})
	shipping = shipping_container[0].text.strip()

	print("\n product :",i)
	i=i+1

	print("brand : "+brand)
	print("product_name : "+product_name)
	print("shipping : "+shipping)


   
	f.write(brand+ "," +product_name.replace(",","|")+ "," +shipping+ "\n")

f.close()
# Out:
#  product : 1
# brand : Sapphire Tech
# product_name : Sapphire Radeon NITRO+ RX 580 4GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)
# shipping :
#
#  product : 2
# brand : MSI
# product_name : MSI GeForce GTX 1050 Ti DirectX 12 GTX 1050 Ti 4G OC 4GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 3
# brand : MSI
# product_name : MSI GeForce GTX 1060 DirectX 12 GTX 1060 AERO ITX 3G OC 3GB 192-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 4
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GT 1030 2GB (VCGGT10302PB)
# shipping :
#
#  product : 5
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1050 Ti DirectX 12 ZT-P10510A-10L 4GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 6
# brand : GIGABYTE
# product_name : GIGABYTE HD Experience Series GeForce 210 DirectX 10.1 GV-N210SL-1GI 1GB 64-Bit DDR3 PCI Express 2.0 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 7
# brand : GIGABYTE
# product_name : GIGABYTE Ultra Durable 2 Series GeForce GT 730 DirectX 12 GV-N730-2GI (rev. 1.0) 2GB 128-Bit DDR3 PCI Express 2.0 HDCP Ready ATX Video Card
# shipping :
#
#  product : 8
# brand : EVGA
# product_name : EVGA GeForce GT 730 DirectX 12 01G-P3-3730-KR 1GB 64-Bit GDDR5 PCI Express 2.0 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 9
# brand : GIGABYTE
# product_name : GIGABYTE Radeon RX 470 DirectX 12 GV-RX470G1 GAMING-4G 4GB 256-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 10
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 1080 DirectX 12 VCGGTX10808XGPB-OC 8GB 256-Bit GDDR5X PCI Express 3.0 x16 SLI Support XLR8 Gaming OC Edition Video Card
# shipping :
#
#  product : 11
# brand : ASUS
# product_name : ASUS ROG Strix Radeon RX 560 O4GB Gaming OC Edition GDDR5 DP HDMI DVI AMD Graphics Card (ROG-STRIX-RX560-O4G-GAMING)
# shipping :
#
#  product : 12
# brand : ASUS
# product_name : Asus R5230-SL-2GD3-L Radeon R5 230 Graphic Card - 650 MHz Core - 2 GB DDR3 SDRAM - PCI Express 2.1 - Low-profile
# shipping :
#
#  product : 13
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping :
#
#  product : 14
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1080 Ti DirectX 12 GV-N108TGAMINGOC BLACK-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 15
# brand : MSI
# product_name : MSI Radeon RX 550 DirectX 12 RX 550 2GT LP OC 2GB 128-Bit GDDR5 PCI Express x16 (uses x8) HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 16
# brand : EVGA
# product_name : EVGA 200 GeForce 210 DirectX 10.1 01G-P3-1312-LR 1GB 64-Bit DDR3 PCI Express 2.0 x16 HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 17
# brand : EVGA
# product_name : EVGA GeForce 210 DirectX 10.1 512-P3-1310-LR 512MB 32-Bit DDR3 PCI Express 2.0 x16 HDCP Ready Low Profile Video Card
# shipping :
#
#  product : 18
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1070 DirectX 12 GV-N1070WF2OC-8GD 8GB 256-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
#
#  product : 19
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1070 DirectX 12 GV-N1070G1 GAMING-8GD R2 256-Bit GDDR5 PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping :
#
#  product : 20
# brand : MSI
# product_name : MSI Radeon R7 250 DirectX 12 R7 250 2GD3 OC 2GB 128-Bit DDR3 PCI Express 3.0 HDCP Ready CrossFireX Support Video Card
# shipping :
#
#  product : 21
# brand : GIGABYTE
# product_name : GIGABYTE AORUS Xtreme GeForce GTX 1080 Ti Waterforce 11GD
# shipping :
#
#  product : 22
# brand : EVGA
# product_name : EVGA GeForce GT 710 DirectX 12 02G-P3-2712-KR 2GB 64-Bit DDR3 PCI Express 2.0 Video Card
# shipping :
#
#  product : 23
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 FTW2 GAMING iCX, 08G-P4-6676-KR, 8GB GDDR5, RGB LED, 9 Thermal Sensors, Asynchronous Fan Control, Thermal Display LED System, Optimized Airflow Fin Design
# shipping :
#
#  product : 24
# brand : Lenovo
# product_name : Lenovo 4X60M28228 Nvidia Quadro M2000 - Graphics Card - Quadro M2000 - 4 Gb - 4 X Displayport - For Thinkstation P410, P510
# shipping :
#
#  product : 25
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 1060 DirectX 12 VCGGTX10603PB 3GB 192-Bit GDDR5 PCI Express 3.0 x16 Video Card
# shipping :
#
#  product : 26
# brand : ZOTAC
# product_name : ZOTAC GeForce GT 730 DirectX 12 (feature level 11_0) ZT-71113-20L 2GB 64-Bit DDR3 PCI Express 2.0 x16 (x8 lanes) HDCP Ready Zone Edition Video Card
# shipping :
#
#  product : 27
# brand : ZOTAC
# product_name : ZOTAC GeForce GT 730 DirectX 12 ZT-71118-10L 4GB 64-Bit DDR5 PCI Express 2.0 x 8 HDCP Ready Low Profile Ready Video Card
# shipping :
#
#  product : 28
# brand : XFX
# product_name : XFX RS XXX Edition Radeon RX 570 DirectX 12 RX-570P427D6 4GB OC+ 1284 MHz XFX Custom Backplate 256-Bit DDR5 PCI Express 3.0 CrossFireX Support Video Card
# shipping :
#
#  product : 29
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS X-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 ATX Xtreme Edition Video Card
# shipping :
#
#  product : 30
# brand : ASUS
# product_name : ASUS GeForce GTX 1060 STRIX-GTX1060-6G-GAMING 6GB 192-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 31
# brand : MSI
# product_name : MSI Black Radeon RX Vega 64 DirectX 12 RADEON RX VEGA 64 8G 8GB 2048-Bit HBM2 PCI Express 3.0 x16 HDCP Ready CrossFireX Support Video Card - Black Fan
# shipping :
#
#  product : 32
# brand : MSI
# product_name : MSI GeForce GTX 1050 DirectX 12 GTX 1050 AERO ITX 2G OC 2GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping :
#
#  product : 33
# brand : MSI
# product_name : MSI GeForce GTX 1080 Ti DirectX 12 GTX 1080 Ti LIGHTNING X 11GB 352-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# shipping :
#
#  product : 34
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1050 DirectX 12 ZT-P10500A-10L 2GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# shipping :
#
#  product : 35
# brand : MSI
# product_name : MSI GeForce GT 730 DirectX 12 N730-2GD3V3 2GB 128-Bit DDR3 PCI Express 2.0 x16 HDCP Ready ATX Video Card
# shipping :
#
#  product : 36
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)
# shipping :

# %%
page_soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
# <script src="//assets.adobedtm.com/d2f967b83a0c92b19d9b572545fdbdc3d591f6f5/satelliteLib-389760a7bc4573d6b081d36f6782b59f3c8ffb54.js"></script>
# <title>graphics card - Newegg.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="always" name="referrer">
# <meta content="Newegg.com - graphics card" name="keywords">
# <meta content="Newegg.com offers the best prices on computer products, laptop computers, LED LCD TVs, digital cameras, electronics, unlocked phones, office supplies, and more with fast shipping and top-rated customer service. Once you know, you Newegg!" name="description">
# <meta content="https://images10.newegg.com/WebResource/Themes/2005/Nest/logo_424x210.png" property="og:image">
# <meta content="Newegg.com offers the best prices on computer products, laptop computers, LED LCD TVs, digital cameras, electronics, unlocked phones, office supplies, and more with fast shipping and top-rated customer service. Once you know, you Newegg!" property="og:description">
# <meta content="d08b8c829bab9a46-ac914e23c0a3607a-g7fba27d07436db8a-e" name="google-translate-customization">
# <meta content="english" name="language">
# <meta content="© 2000-2017 Newegg International Inc." name="copyright">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="index,follow" name="robots">
# <link href="https://www.newegg.com/global/in/Product/ProductList.aspx?Description=graphics%20card&amp;Submit=ENE" rel="canonical"/>
# <link href="https://www.newegg.com/global/in/Product/RSS.aspx?Submit=ENE&amp;IsNodeId=1&amp;Description=graphics%20card&amp;ShowDeactivatedMark=False" rel="alternate" title="Newegg Product List" type="application/rss+xml">
# <link href="//images10.newegg.com/WebResource/Themes/2005/Nest/Newegg.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,700,700italic|Open+Sans+Condensed:300,300italic,700" rel="stylesheet" type="text/css">
# <link href="//images10.newegg.com/WebResource/Themes/2005/CSS/USA/WWWShared.13802.5.min.css" rel="stylesheet" type="text/css"/>
# <link href="//images10.newegg.com/WebResource/Themes/2005/CSS/USA/WWWProductList2016.13660.3.min.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var nebs = nebs||{};nebs.errors = [];window.onerror = function(){nebs.errors.push(arguments);return true;};</script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/NeweggJS/NEG.0.2.2.js" type="text/javascript"></script>
# <script type="text/javascript">(function(NEG){if(NEG && NEG.setVersion){NEG.setVersion([{"module":"Biz.Cookie","version":"12376"},{"module":"Biz.Storage","version":"13637.2"},{"module":"Biz.InvodoVideo","version":"9792"},{"module":"Biz.Items","version":"9792"},{"module":"Biz.Resource","version":"9792"},{"module":"Biz.SearchKeywords","version":"9792"},{"module":"NEG.Utility.QueryStringBuilder","version":"11847"},{"module":"NEG.Widget.History","version":"9792"},{"module":"NEG.Widget.ImageZoomer","version":"13375.1"},{"module":"NEG.Widget.Mask","version":"10825"},{"module":"NEG.Widget.RangeSlider","version":"12739.0"},{"module":"NEG.Widget.Scroll","version":"9792"},{"module":"NEG.Widget.Viewport","version":"9792"},{"module":"NEG.Widget.Popup","version":"11629"},{"module":"Widget.Switch","version":"11315"},{"module":"NEG.Widget.AutoConfigurator","version":"10825.1"},{"module":"NEG.Widget.FilterManager.Model","version":"10520"},{"module":"NEG.Widget.FilterManager.View","version":"10520"},{"module":"NEG.Widget.PropertyManager.Model","version":"10520.2"},{"module":"NEG.Widget.PropertyManager.ViewManager","version":"10520.2"},{"module":"Utility.Cookie","version":"11621.1"},{"module":"Utility.JQuery","version":"12376"},{"module":"NEG.ThirdParty.JQuery","version":"12376"},{"module":"Biz.Common.Popup","version":"13760.1"},{"module":"Biz.Common.RecentlyView2016","version":"13025.1"},{"module":"Biz.Common.RecentlyView2012","version":"13025.1"},{"module":"Biz.Product.ProductPersonalization","version":"13601.0"},{"module":"Biz.Product.MiniFeatures","version":"13025.0"}]);}})(NEG);</script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/TP_jQueryPlugin/jquery-1.10.2.min.js?purge=1" type="text/javascript"></script>
# <script type="text/javascript">if(!(typeof jQuery==='undefined')){if($===jQuery){jQuery.noConflict();}}</script>
# <script type="text/javascript">if(sessionStorage.isEDUip_Newegg!="false" && sessionStorage.isEDUip_Newegg!="true"){jQuery.ajax({type: "GET",async: true,timeout:3000,url: "https://www.newegg.com/global/in/Common/Ajax/CheckEDUByIP.aspx",success: function(response){if (response) {var str = response.toString();if (str && str.indexOf("true") > -1) {window.isEDUip = "true";} else {window.isEDUip = "false";}} else {window.isEDUip = "false";}sessionStorage.isEDUip_Newegg=window.isEDUip;}});}else{window.isEDUip=sessionStorage.isEDUip_Newegg;}</script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/TP_jQueryPlugin/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/TP_jQueryPlugin/popup.js" type="text/javascript"></script>
# <script type="text/javascript">var nt_serverName="E4WEB13";var CANSite="//www.newegg.ca";var DOMAIN_NAME=".newegg.com",DOMAIN_TEXT="Newegg.com";if(!window["Web"]){Web={};};Web["Config"]={Environment:{Url:{WWW:'https://www.newegg.com/global/in/',Shopper:'https://secure.newegg.com/',Secure:'https://secure.newegg.com/',Content:'https://www.newegg.com/global/in/',CDN:'https://www2.newegg.com/global/in/',HttpCache:'//images10.newegg.com/WebResource/',HttpsCache:'//images10.newegg.com/WebResource/',HttpJSCache:'//images10.newegg.com/WebResource/',HttpsJSCache:'//images10.newegg.com/WebResource/',Local:'/WebResource/',Language:'en-US'},SSLPage:{Login:'https://secure.newegg.com/NewMyAccount/AccountLogin.aspx?nextpage=https%3a%2f%2fwww.newegg.com%2fglobal%2fin%2fProduct%2fProductList.aspx%3fSubmit%3dENE%26DEPA%3d0%26Order%3dBESTMATCH%26Description%3dgraphics%2520card%26N%3d-1%26isNodeId%3d1',Loginout:'https://secure.newegg.com/NewMyAccount/AccountLogout.aspx',MyAccountIndex:'https://secure.newegg.com/NewMyAccount/Index.aspx',Shoppingcart:'https://secure.newegg.com/Shopping/ShoppingCart.aspx',AddTocart:'https://secure.newegg.com/Shopping/AddToCart.aspx',ActivePoint:'https://secure.newegg.com/NewMyAccount/ActivePoints.aspx',NewMyAccountAutoNotify:'https://secure.newegg.com/NewMyAccount/AutoNotify.aspx'},Path:{Images:'Themes/2005/Nest/',Scripts:'Scripts/',Css:'Themes/2005/CSS/'},Cookies:{EnableCookieNameMapping:1},AutoFillBold:{Enable:true,UseContentPage:true},IE11VersionUpgrade:true,NeweggGlobalUrl:'http://promotions.newegg.com/international/global/index.html',WWWPage:{B2BSepEnable: false,IsHomepage: false,IsProductList: true,IsNewStoreAndList: true,IsDailyDealStore: true,IsSubcategory: false,NeweggGlobalStore:'https://www.newegg.com/Newegg-Global/Store',ProductListEnableRightSide:true},SyncShoppingCart:{MinicartServiceEnable:true,ItemPriceLink:'https://secure.newegg.com/Common/Ajax/MiniCartService.aspx',ItemDetailLink:'https://secure.newegg.com/Common/Ajax/MiniCartService.aspx?IsDetail=true',}},CookieMapping:{'NV_CONFIGURATION':['.newegg.com',86400000,'',false],'NV_PRDLIST':['.newegg.com',86400000,'',false],'NV_ADVSEARCHOPEN':['.newegg.com',86400000,'',false],'NV_CUSTOMERLOGIN':['.newegg.com',0,'',true],'NV_AFFILIATECUSTOMER':['.newegg.com',604800,'',false],'NV_HBXCM':['.newegg.com',86400000,'',false],'NV_ADVSEARCHOPEN':['.newegg.com',86400000,'',false],'NV_CONTACTUS_COOKIE':['.newegg.com',86400000,'',false],'NV_VENDOR_NEWS_LIST':['.newegg.com',86400000,'',false],'CELL_PHONE_COMBO':['.newegg.com',86400000,'',false],'CELL_PHONE_PACKAGE':['',86400000,'',false],'NV_THANKYOUTRACKCOOKIE':['.newegg.com',86400,'',false],'NV_CDICOOKIE':['.newegg.com',10800,'',false],'NV_CUSTOMERREVIEWCOOKIE':['',86400000,'',false],'NV_GOOGLE_ANALYTICS':['.newegg.com',2592000,'',false],'NV_DVINFO':['.newegg.com',0,'',false],'NV_THIRD_PARTY':['.newegg.com',2592000,'',false],'NV_NEWGOOGLE_ANALYTICS':['.newegg.com',2592000,'',false],'NV_CUSTOMERLOGININTERNALUSER':['.newegg.com',0,'',false],'NV_B2BCUSTOMERLOGIN':['.newegg.com',0,'',true],'NV_TESTCOOKIE':['.newegg.com',0,'',false],'NV_MyNeweggModule':['.newegg.com',2592000,'',false],'AB':['.newegg.com',0,'',false],'NV_SURVEY':['.newegg.com',2592000,'',false],'NV_CERTONA':['.newegg.com',86400,'',false],'NV_FV':['.newegg.com',0,'',false],'NV_WISHLIST':['.newegg.com',2592000,'',false],'NV_COUNTRY':['.newegg.com',2592000,'',false],'NV_OTHERINFO':['.newegg.com',0,'',false],'NVTC':['.newegg.com',2592000,'',false],'NV_RECENTLYVIEWEDS':['.newegg.com',2592000,'',false],'NV_SPT':['.newegg.com',0,'',false],'NV_NEWEGGCOOKIE':['.newegg.com',0,'',false],'NV_LOCALSTORAGE':['.newegg.com',86400000,'',false],'NV_NID':['.newegg.com',2592000,'',false]},SiteCookieInfo:{bizUnit:"USA",enableReformattedCookie:true,writeReformattedCookie:true},NVTC:{UTMAExpireTime:30,SiteID:"0001"},SiteCatalyst:{Enable:true},recaptchaKey:"6Ld0av8SAAAAAA_bWcLCPqT109QEfdRp0w50GCsq"};Web["Lang"]={"account":"Account Settings","activity":"Activity","addNewVehicle ...
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/GgewenFramework.v1.w.13720.em.6.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/WebApplication.v1.w.13527.0.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/PageDisplayLib.v1.w.13660.1.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/AutoFilledKeywords.v1.w.13556.0.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/BizCommon.v1.w.13836.0.e1.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/json2.min.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/swfobject.v1.5.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/Common/swiper.min.3.4.2.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/WWW/SearchPanel2016.v1.w.13660.8.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/WWW/ProductList2016.v1.w.13660.1.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/WWW/AutoConfiguratorStripe2016.v1.w.13382.0.js" type="text/javascript"></script>
# <script src="//images10.newegg.com/WebResource/Scripts/USA/WWW/Store.v1.w.13308.11.js" type="text/javascript"></script>
# <!-- Begin Monetate ExpressTag Sync v8.1. Place at start of document head. DO NOT ALTER. -->
# <script type="text/javascript">var monetateT = new Date().getTime();</script>
# <script src="//se.monetate.net/js/2/a-f0e60b81/p/newegg.com/entry.js" type="text/javascript"></script>
# <!-- End Monetate tag. -->
# <script language="javascript" type="text/javascript">Web.Caching.SyncCookie('[{\"name\":\"NV_CONFIGURATION\",\"changeCookieValues\":[{\"key\":\"DEPA\",\"value\":\"0\"},{\"key\":\"RegionCode\",\"value\":\"IND\"},{\"key\":\"CurrencyCode\",\"value\":\"INR\"}],\"expire\":0},{\"name\":\"NV_PRDLIST\",\"changeCookieValues\":[{\"key\":\"BestMatch\",\"value\":\"Y\"},{\"key\":\"SortBy\",\"value\":\"BESTMATCH\"}],\"expire\":0},{\"name\":\"NV_DVINFO\",\"changeCookieValues\":[{\"key\":\"PCID\",\"value\":\"Y\"}],\"expire\":0}]');</script>
# <script type="text/javascript">Biz.Common.SearchKeywords.saveInnerSearchKaywords("graphics card");</script>
# <script type="text/javascript">if(top.location!=self.location){top.location.replace(self.location);}</script>
# <!--[if lt IE 9]><script type="text/javascript" src="//images10.newegg.com/WebResource/Scripts/USA/TP_Html5/Html5.js" ></script><![endif]-->
# </link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="NEGlobal productListPage cells">
# <span class="noCSS">Skip to:</span>
# <a class="skiplink" href="#startContent">Content</a>
# <a name="startContent"><span style="display: none">|</span></a>
# <span class="noCSS">|</span>
# <a class="skiplink" href="#footerArea">Footer</a>
# <a name="top"></a>
# <div id="visionImpaired" style="position:absolute;left:0;top:-999px;"></div>
# <div id="message2OlderBrowser">
# <p>Newegg.com - A great place to buy computers, computer parts, electronics, software, accessories, and DVDs online. With great prices, fast shipping, and top-rated customer service - once you know, you Newegg.</p>
# <p>If you are reading this message, <b>Please  <a href="javascript:void(0);" onclick="window.location = window.location.href;">click this link</a> to reload this page.(Do not use your browser's "Refresh" button).</b>  Please <a href="mailto:webmaster@newegg.com">email us</a> if you're running the latest version of your browser and you still see this message.</p>
# <p><a href="https://www.newegg.com/global/in">Newegg.com - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!</a></p>
# </div>
# <noscript>
# 	If you see this message, your web browser doesn't support JavaScript or JavaScript is disabled.
# 	Please enable JavaScript in your browser settings so Newegg.com can function correctly.
# 	</noscript>
# <!-- begin: header -->
# <header class="header">
# <div class="header-inner">
# <div class="header-logo">
# <a class="header-logo-img" href="https://www.newegg.com/global/in" title="Newegg.com - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!">
# <img alt="Newegg.com- Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!" src="//images10.newegg.com/WebResource/Themes/2005/Nest/logo_424x210.png"/></a>
# <div class="header-logo-bg"></div>
# </div>
# <!-- begin: header tabs -->
# <div class="header-tabs">
# <ul class="header-subsites">
# <li class="header-subsite">
# <a class="header-feedback" id="guest_feedback" onclick="javascript:newegg_inhouse_feedback &amp;&amp; newegg_inhouse_feedback.show();" style="cursor:pointer"><ins>Feedback</ins></a>
# </li>
# </ul>
# <div class="fix"></div>
# </div>
# <!-- end: header tabs -->
# <!-- begin: header top nav -->
# <nav class="top-nav">
# <input id="hiddenOrderInfo" is-update="0" name="hiddenOrderInfo" type="hidden" value=""/>
# <input id="switch_premier2016" type="hidden" value="False">
# <ul class="top-nav-tabs">
# <!--Region-->
# <li class="top-nav-tab">
# <label class="top-nav-tab-name country-change" for="CountryList" id="NEGlobal-CountryDropdown">
# <select id="CountryList" title="Select a Country">
# <optgroup label="North America">
# <option data-countrycode="can" data-localcurrency="USD" data-twolettercode="ca" value="CAN">Canada</option>
# <option data-countrycode="mex" data-localcurrency="MXN" data-twolettercode="mx" value="MEX">Mexico</option>
# <option data-countrycode="usa" data-localcurrency="USD" data-twolettercode="us" value="USA">United States</option>
# </optgroup>
# <optgroup label="Oceania">
# <option data-countrycode="aus" data-localcurrency="AUD" data-twolettercode="au" value="AUS">Australia</option>
# <option data-countrycode="nzl" data-localcurrency="NZD" data-twolettercode="nz" value="NZL">New Zealand</option>
# </optgroup>
# <optgroup label="South America">
# <option data-countrycode="chl" data-localcurrency="CLP" data-twolettercode="cl" value="CHL">Chile</option>
# <option data-countrycode="col" data-localcurrency="COP" data-twolettercode="co" value="COL">Colombia</option>
# <option data-countrycode="ecu" data-localcurrency="USD" data-twolettercode="ec" value="ECU">Ecuador</option>
# </optgroup>
# <optgroup label="Central America">
# <option data-countrycode="cri" data-localcurrency="CRC" data-twolettercode="cr" value="CRI">Costa Rica</option>
# <option data-countrycode="dom" data-localcurrency="DOP" data-twolettercode="do" value="DOM">Dominican Republic</option>
# <option data-countrycode="hnd" data-localcurrency="HNL" data-twolettercode="hn" value="HND">Honduras</option>
# <option data-countrycode="jam" data-localcurrency="JMD" data-twolettercode="jm" value="JAM">Jamaica</option>
# <option data-countrycode="nic" data-localcurrency="NIO" data-twolettercode="ni" value="NIC">Nicaragua</option>
# <option data-countrycode="pan" data-localcurrency="PAB" data-twolettercode="pa" value="PAN">Panama</option>
# </optgroup>
# <optgroup label="Asia">
# <option data-countrycode="hkg" data-localcurrency="HKD" data-twolettercode="hk" value="HKG">Hong Kong</option>
# <option data-countrycode="ind" data-localcurrency="INR" data-twolettercode="in" selected="selected" value="IND">India</option>
# <option data-countrycode="idn" data-localcurrency="IDR" data-twolettercode="id" value="IDN">Indonesia</option>
# <option data-countrycode="isr" data-localcurrency="ILS" data-twolettercode="il" value="ISR">Israel</option>
# <option data-countrycode="mac" data-localcurrency="MOP" data-twolettercode="mo" value="MAC">Macau</option>
# <option data-countrycode="phl" data-localcurrency="PHP" data-twolettercode="ph" value="PHL">Philippines</option>
# <option data-countrycode="sau" data-localcurrency="SAR" data-twolettercode="sa" value="SAU">Saudi Arabia</option>
# <option data-countrycode="sgp" data-localcurrency="SGD" data-twolettercode="sg" value="SGP">Singapore</option>
# <option data-countrycode="kor" data-localcurrency="KRW" data-twolettercode="kr" value="KOR">South Korea</option>
# <option data-countrycode="tha" data-localcurrency="THB" data-twolettercode="th" value="THA">Thailand</option>
# <option data-countrycode="tur" data-localcurrency="TRY" data-twolettercode="tr" value="TUR">Turkey</option>
# <option data-countrycode="are" data-localcurrency="AED" data-twolettercode="ae" value="ARE">United Arab Emirates</option>
# </optgroup>
# <optgroup label="Europe">
# <option data-countrycode="aut" data-localcurrency="EUR" data-twolettercode="at" value="AUT">Austria</option>
# <option data-countrycode="bel" data-localcurrency="EUR" data-twolettercode="be" value="BEL">Belgium</option>
# <option data-countrycode="bgr" data-localcurrency="BGN" data-twolettercode="bg" value="BGR">Bulgaria</option>
# <option data-countrycode="dnk" data-localcurrency="DKK" data-twolettercode="dk" value="DNK">Denmark</option>
# <option data-countrycode="fin" data-localcurrency="EUR" data-twolettercode="fi" value="FIN">Finland</option>
# <option data-countrycode="fra" data-localcurrency="EUR" data-twolettercode="fr" value="FRA">France</option>
# <option data-countrycode="deu" data-localcurrency="EUR" data-twolettercode="de" value="DEU">Germany</option>
# <option data-countrycode="grc" data-localcurrency="EUR" data-twolettercode="gr" value="GRC">Greece</option>
# <option data-countrycode="hun" data-localcurrency="HUF" data-twolettercode="hu" value="HUN">Hungary</option>
# <option data-countrycode="irl" data-localcurrency="EUR" data-twolettercode="ie" value="IRL">Ireland</option>
# <option data-countrycode="ita" data-localcurrency="EUR" data-twolettercode="it" value="ITA">Italy</option>
# <option data-countrycode="lva" data-localcurrency="EUR" data-twolettercode="lv" value="LVA">Latvia</option>
# <option data-countrycode="lux" data-localcurrency="EUR" data-twolettercode="lu" value="LUX">Luxembourg</option>
# <option data-countrycode="mco" data-localcurrency="EUR" data-twolettercode="mc" value="MCO">Monaco</option>
# <option data-countrycode="nld" data-localcurrency="EUR" data-twolettercode="nl" value="NLD">Netherlands</option>
# <option data-countrycode="nor" data-localcurrency="NOK" data-twolettercode="no" value="NOR">Norway</option>
# <option data-countrycode="pol" data-localcurrency="PLN" data-twolettercode="pl" value="POL">Poland</option>
# <option data-countrycode="prt" data-localcurrency="EUR" data-twolettercode="pt" value="PRT">Portugal</option>
# <option data-countrycode="svk" data-localcurrency="EUR" data-twolettercode="sk" value="SVK">Slovakia</option>
# <option data-countrycode="svn" data-localcurrency="EUR" data-twolettercode="si" value="SVN">Slovenia</option>
# <option data-countrycode="esp" data-localcurrency="EUR" data-twolettercode="es" value="ESP">Spain</option>
# <option data-countrycode="swe" data-localcurrency="SEK" data-twolettercode="se" value="SWE">Sweden</option>
# <option data-countrycode="che" data-localcurrency="CHF" data-twolettercode="ch" value="CHE">Switzerland</option>
# <option data-countrycode="gbr" data-localcurrency="GBP" data-twolettercode="gb" value="GBR">United Kingdom</option>
# </optgroup>
# </select>
# <span class="top-nav-tab-icon flag in"></span>
# <i class="fa fa-caret-down"></i>
# </label>
# </li>
# <script type="text/javascript">Biz.Common.TopNavigation.flagPageHeader();</script>
# <!--Account-->
# <li class="top-nav-tab " id="usaSite">
# <script type="text/javascript">Biz.Common.TopNavigation.loginPageHeader2015();</script>
# </li>
# <!--ShoppingCart-->
# <li class="top-nav-tab" id="miniCart">
# <script type="text/javascript">prepareMiniCartInfo(true)</script>
# </li>
# <li class="top-nav-tab menu-align-right has-menu" id="liWishList">
# <a class="top-nav-tab-name" href="javascript:void(0);"><i class="top-nav-tab-icon fa fa-heart"></i><ins>Wish List</ins></a>
# <div class="top-nav-menu">
# <i class="fa fa-caret-down"></i><i class="top-nav-menu-arrow"></i>
# <div class="top-nav-menu-inner">
# <ul class="top-nav-menu-links">
# <li><a href="https://secure.newegg.com/WishList/MyWishlists">My Wish Lists</a></li>
# <li><a href="https://secure.newegg.com/WishList/FollowWishlists">Followed Wish Lists</a></li>
# <li><a href="https://secure.newegg.com/WishList/PublicWishlists">Public Wish Lists</a></li>
# </ul>
# </div>
# </div>
# </li>
# <script type="text/javascript">
#
#                 var wishlistPageUrlAlias = {
#                     WishListAjaxMiddlePage: "https://secure.newegg.com/Common/Ajax/WishListAjaxMiddlePage.aspx",
#                     MyWishListDetail: "https://secure.newegg.com/Wishlist/MyWishlistDetail",
#                     MyWishLists: "https://secure.newegg.com/WishList/MyWishlists"
#                 };
#
#                 jQuery(document).ready(function () {
#                     Biz.Common.TopNavigation.setWishlist(wishlistPageUrlAlias.WishListAjaxMiddlePage, wishlistPageUrlAlias.MyWishListDetail, wishlistPageUrlAlias.MyWishLists);
#                 });
#             </script>
# <li class="top-nav-tab menu-align-right has-menu"><a class="top-nav-tab-name" href="javascript:void(0);"><i class="top-nav-tab-icon fa fa-question-circle"></i><ins>Customer Service</ins> </a>
# <div class="top-nav-menu">
# <i class="fa fa-caret-down"></i><i class="top-nav-menu-arrow"></i>
# <div class="top-nav-menu-inner">
# <ul class="top-nav-menu-links">
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=1" id="headerTrackOrder">Track An Order</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=4" id="findInvoice">Find Invoice</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=2" id="headerReturnItem">Return An Item</a></li>
# <li><a href="https://secure.newegg.com/Guest/OrderLogin.aspx?Source=3" id="checkReturnStatus">Check Return Status</a></li>
# <li><a href="//www.newegg.com/Special/Rebate.aspx?name=Rebate-Center">Find Rebates</a></li>
# <li class="top-nav-menu-split"><a href="https://kb.newegg.com/"><i class="fa fa-info-circle"></i> Customer Self-Help</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </input></nav>
# <script type="text/javascript">
#     jQuery(document).ready(function () { Biz.Common.TopNavigation.setLink(); });
# </script>
# <!-- end: header top nav -->
# </div>
# <nav class="nav-bar">
# <div class="nav-bar-inner fix">
# <div class="nav-row">
# <div class="nav-col">
# <div class="btn-group">
# <!-- begin: site main nav -->
# <nav class="btn-group-cell menu-box main-nav" id="menu_async">
# <a class="btn btn-primary has-icon-right fa-caret-down main-nav-title" href="javascript:void(0);">All Products</a>
# <div class="menu-box-body">
# <i class="menu-box-arrow"></i>
# <div class="menu-box-body-inner" id="main-nav-menu-list">
# <ul class="main-nav-categories">
# </ul>
# </div>
# </div>
# </nav>
# <!-- end: site main nav -->
# <!-- begin: marketplace nav -->
# <!-- end: marketplace nav -->
# </div>
# </div>
# <div class="nav-col nav-col-elastic">
# <!-- begin: search bar -->
# <div class="search-bar haFormQuickSearchTextboxWrapper" id="newHeaderSearchTools">
# <script type="text/javascript">
#         usingNamespace("Biz.Search")["RegionAutoFilledKeywords"] = {
#             disable: 0
#             };
#     </script>
# <form action="https://www.newegg.com/global/in/Product/ProductList.aspx" id="haFormQuickSearch" method="get" name="haFormQuickSearch" onsubmit="return Biz.Common.QuickSearch.submitPagehHeader2011();">
# <input name="Submit" title="Submit" type="hidden" value="ENE">
# <input name="DEPA" title="DEPA" type="hidden" value="0">
# <input name="Order" title="Order" type="hidden" value="BESTMATCH">
# <input id="isNewHeaderTool" type="hidden" value="1">
# <div class="nav-row search-bar-inner">
# <div class="nav-col nav-col-elastic search-bar-keywords" id="haQuickSearchTextbox">
# <input autocomplete="off" id="haQuickSearchBox" maxlength="268" name="Description" onblur="Biz.Common.QuickSearch.inputFocus(false)" onfocus="Biz.Common.QuickSearch.inputFocus(true)" onwebkitspeechchange="this.value=(this.value).replace(/Keywords, Model # or Item #/,'')" title="Search Site" type="search" value="graphics card">
# <script type="text/javascript">Biz.Common.QuickSearch.chromeSpeechSearch(); </script>
# <div class="search-bar-auto-filled" id="autofilledview"></div>
# <iframe id="iframeKeywords" name="iframeKeywords" src="//images10.newegg.com/WebResource/Themes/2005/Nest/blank.html" style="width: 0; height: 0; display: none;" title="iframeKeywords">iframe for layout</iframe>
# </input></div>
# <!--QuickSearchDropdown-->
# <div class="nav-col" id="haQuickSearchDropdown">
# <label class="form-select search-bar-category">
# <select id="haQuickSearchStore" title="Select a store">
# <option selected="selected" value="-1">Search all</option><option value="100203988">Apparel &amp; Accessories</option><option value="100203941">Components</option><option value="100203942">Computer Systems</option><option value="100203945">Electronics</option><option value="100203944">Gaming</option><option value="100203955">Health &amp; Sports</option><option value="100203947">Hobbies &amp; Toys</option><option value="100203952">Home &amp; Tools</option><option value="100203987">Networking</option><option value="100203946">Office Solutions</option>
# </select>
# <span class="form-select-name">Search all</span> <i class="fa fa-caret-down"></i>
# <input id="N" name="N" title="N" type="hidden" value="-1">
# <input name="isNodeId" title="isNodeId" type="hidden" value="1">
# <input id="BRID" title="BRID" type="hidden" value="">
# </input></input></input></label>
# </div>
# <div class="nav-col">
# <button class="btn btn-primary btn-mini search-bar-btn" onclick="javascript:Biz.Search.AutoFilledKeywordsNew.search()" type="button">Search</button>
# </div>
# </div>
# </input></input></input></input></form>
# </div>
# <!-- end: search bar -->
# </div>
# </div>
# </div>
# </nav>
# </header>
# <iframe id="commonIframe" name="commonIframe" src="//images10.newegg.com/WebResource/Themes/2005/Nest/blank.html" style="width: 0; height: 0; display: none;" title="commonIframe">
#     iframe for layout
# </iframe>
# <!-- end: header -->
# <script type="text/javascript">
#         (function () {
#             var getUtma = function (utmaAry) {
#                 return utmaAry.join(".");
#             };
#             var getDomainHash = function (a) {
#                 var b = 1, c = 0, d = 0, b = 0;
#                 if (a) {
#                     for (d = a.length - 1; 0 <= d; d--) {
#                         c = a.split(/(?=[\w\W])/)[d].charCodeAt();
#                         b = (b << 6 & 268435455) + c + (c << 14);
#                         c = b & 266338304;
#                         b = 0 != c ? b ^ c >> 21 : b;
#                     }
#                 }
#                 return b;
#             };
#             var totalSeconds = Date.parse(new Date()) / 1000;
#             var random = Math.floor(Math.random() * 1000000000);
#             var getUTMAExpireTime = function () {
#                 return 30;
#             };
#             var generate = function (domain, siteID) {
#                 var domainHash = getDomainHash(domain);
#                 if (domainHash == 0) {
#                     return "";
#                 }
#                 var id = random;
#                 var ct = totalSeconds;
#
#                 var utmaAry = new Array(7);
#                 utmaAry[0] = domainHash.toString();
#                 utmaAry[1] = siteID;
#                 utmaAry[2] = id.toString();
#                 utmaAry[3] = ct;
#                 utmaAry[4] = ct;
#                 utmaAry[5] = ct;
#                 utmaAry[6] = "1";
#
#                 return getUtma(utmaAry);
#             };
#             var refresh = function (utma, domain, siteID) {
#                 var utmaAry = utma.split(".");
#                 if (utmaAry.length == 1) {
#                     return generate(domain, siteID);
#                 }
#                 if (utmaAry.length != 7) {
#                     return utma;
#                 }
#
#                 var domainHash = getDomainHash(domain);
#                 if ((domainHash + "." + siteID) != (utmaAry[0] + "." + utmaAry[1])) {
#                     return generate(domain, siteID);
#                 }
#
#                 var currentAccessTime = totalSeconds;
#
#                 var nvtcTimeStampCookie;
#                 var array, nvtcTimeStampRegex = new RegExp("NV_NVTCTIMESTAMP=([^;]*)(;|$)");
#                 if (array = document.cookie.match(nvtcTimeStampRegex)) {
#                     nvtcTimeStampCookie = array[1];
#                 }
#
#                 if (nvtcTimeStampCookie) {
#                     var nvtcTimeStamp = parseInt(nvtcTimeStampCookie);
#                 }
#                 if (!nvtcTimeStamp || (currentAccessTime - nvtcTimeStamp > getUTMAExpireTime() * 60)) {
#                     utmaAry[4] = utmaAry[5];
#                     utmaAry[5] = currentAccessTime.toString();
#                     utmaAry[6] = parseInt(utmaAry[6]) + 1;
#                     utma = getUtma(utmaAry);
#                 }
#
#                 return utma;
#             };
#             var generateAndUpdate = function () {
#                 try{
#                     var utmaRegex = new RegExp("NVTC=([\\d\\.A-Za-z]*)");
#                     var utmaMatch = utmaRegex.exec(document.cookie);
#                     if (utmaMatch && utmaMatch.length > 1) {
#                         var utma = utmaMatch[1];
#                     }
#                     var match = location.host.match(/\w+\.(\w+[\.\w+]+)/);
#                     var domain;
#                     if (match && match.length > 1) {
#                         domain = match[1];
#                     }
#                     var siteID = "0001";
#                     var expireDate = new Date();
#                     expireDate.setFullYear(expireDate.getFullYear() + 2);
#
#                     if (utma) {
#                         var utmaAry = utma.split(".");
#                         if (utmaAry.length == 7) {
#                             utma = refresh(utma, domain, siteID);
#                         } else {
#                             utma = generate(domain, siteID);
#                         }
#                     } else {
#                         utma = generate(domain, siteID);
#                     }
#                     var nvtcTimeStampExpireDate = new Date();
#                     nvtcTimeStampExpireDate.setUTCDate(nvtcTimeStampExpireDate.getUTCDate() + 1);
#                     document.cookie = "NVTC=" + utma + "; domain=" + domain + "; expires=" + expireDate.toGMTString() + "; path=/";
#                     document.cookie = "NV_NVTCTIMESTAMP=" + totalSeconds + "; domain=" + domain + "; expires=" + nvtcTimeStampExpireDate.toGMTString() + "; path=/";
#                 }
#                 catch (ex) {
#                     if (nebs) {
#                         nebs.errors = nebs.errors || [];
#                         nebs.errors.push(new Error('nvtcex ' + (ex.name || '') + ' ' + (ex.message || '')));
#                     }
#                 }
#             };
#
#             generateAndUpdate();
#         })();
#     </script>
# <script type="text/javascript">
#         Web.Template.RolloverMenu2015.init();
#         Web.Template.PageHeaderDropDownMenu.init();
#     </script>
# <!-- end: header -->
# <!-- begin: breadcrumb and top navigation -->
# <div class="nav-x-body-top-bar-wrap">
# <!-- begin: breadcrumb -->
# <div class="nav-x-body-top-bar fix">
# <ol class="breadcrumb" id="baBreadcrumbTop">
# <li>
# <a href="https://www.newegg.com/global/in/" title="Home - India">Home - India</a>
# </li>
# <li class="is-current">Search Results: "graphics card"</li>
# </ol>
# </div>
# <!-- end: breadcrumb -->
# <!-- begin: top nav bar -->
# <div class="nav-x-body-top-bar fix">
# <script>
#     jQuery(document).ready(function (e) {
#         var objDelayHover = new Biz.Common.TopNavBar.objEven2016('.nav-x>.nav-x-cell.has-menu, .nav-x>.nav-x-cell.has-miniMenu');
#         objDelayHover.delayHover();
#     });
# </script>
# <div class="page-title">
# <h1 class="page-title-text">"graphics card"</h1>
# </div>
# <nav class="nav-x">
# <!--begin: releated searchs rpt-->
# <div class="nav-x-cell">
# <p class="nav-x-title">
# <strong>Related Searches:</strong>
# <a href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;Depa=0&amp;Order=BESTMATCH&amp;Description=gtx%201060&amp;IsRelated=1&amp;cm_sp=KeywordRelated-_-graphics_card-_-gtx%201060" title="gtx 1060">gtx 1060</a>
#                             ,
#
#                             <a href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;Depa=0&amp;Order=BESTMATCH&amp;Description=network%20card&amp;IsRelated=1&amp;cm_sp=KeywordRelated-_-graphics_card-_-network%20card" title="network card">network card</a>
# </p>
# </div>
# <!--end: releated searches -->
# <!--begin: releated normalNav -->
# <div class="nav-x-cell has-miniMenu ">
# <a class="nav-x-title" href="javascript:void(0)">Related Categories<i class="fa fa-caret-down"></i></a>
# <div class="nav-x-menu">
# <ul class=" nav-x-menu-mini ">
# <li>
# <a href="https://www.newegg.com/global/in/Desktop-Graphics-Cards/SubCategory/ID-48" title="Desktop Graphics Cards">Desktop Graphics Cards</a>
# </li>
# <li>
# <a href="https://www.newegg.com/global/in/Workstation-Graphics-Cards/SubCategory/ID-449" title="Workstation Graphics Cards">Workstation Graphics Cards</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="nav-x-cell">
# <a class="nav-x-title" href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;N=4802&amp;IsNodeId=1&amp;Description=graphics%20card&amp;name=Top%20Sellers&amp;Order=BESTMATCH" title="Top Sellers">Top Sellers</a>
# </div>
# <!--end: releated normalNav -->
# <!-- begin: releated comboDealDp -->
# <!-- end: releated comboDealDp -->
# </nav>
# </div>
# <!-- end: top nav bar -->
# </div>
# <!-- end: breadcrumb and top navigation -->
# <!-- begin: page content -->
# <span id="startContent"></span>
# <div class="page-content" id="bodyArea">
# <section class="page-section">
# <div class="page-section-inner">
# <div class="row has-side-left">
# <!-- begin: left side -->
# <div class="row-side">
# <div class="left-nav">
# <!-- common checkbox Scenes -->
# <!--Search Panel Core-->
# <script type="text/javascript">
#     Biz.SearchPanel2016.NavigationListLimit.Config={RequestContent:{Submit:'ENE',sstore:'',havesstore:'',IsNodeId:'1',StoreType:'NonStore',Depa:'0',Category:'-1',SubCategory:'-1',Brand:'-1',Ntk:'',SecondSearch:'False',Description:"graphics card",Configurator:'',CFG:'',ActiveSearchResult:'',FirstFromAsia:'False',PageSize:'0',page:'1',name:"",OEMMark:"",N:'',IsShowItemCount:true}}
# </script>
# <!--powerserarch head-->
# <!--facet-->
# <dl class="filter-box is-category has-menu is-active">
# <dt class="filter-box-title">Department</dt>
# <dd class="filter-box-body">
# <input name="hidNSValue" type="hidden" value="100204377"/>
# <!-- any category, 13133 program add-->
# <div class="filter-box-subtitle has-back-icon">
# <a href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;N=100&amp;IsNodeId=1&amp;Description=graphics%20card&amp;name=Any%20Category&amp;Order=BESTMATCH">Any Category</a>
# </div>
# <!-- common department-->
# <!-- category -->
# <div class="filter-box-subtitle has-back-icon">
# <a href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;N=100204374&amp;IsNodeId=1&amp;Description=graphics%20card&amp;name=Video%20Cards%20%26%20Video%20Devices&amp;Order=BESTMATCH" title="Video Cards &amp; Video Devices">Video Cards &amp; Video Devices</a>
# </div>
# <!-- subcatgory -->
# <ul class="filter-box-list">
# <li>
# <!-- link -->
# <a class="filter-box-label" href="https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&amp;N=100204377&amp;IsNodeId=1&amp;Description=graphics%20card&amp;name=Desktop%20Graphics%20Cards&amp;Order=BESTMATCH&amp;isdeptsrh=1" title="Desktop Graphics Cards">
#                             Desktop Graphics Cards
#                             <span style="display: none;">100204377</span>
# </a>
# <!-- item count -->
# <span class="filter-box-num">(234)</span>
# </li>
# </ul>
# <!-- show more area-->
# </dd>
# </dl>
# <dl class="filter-box has-menu is-active" id="facet250">
# <!--common facet title -->
# <dt class="filter-box-title">Manufacturer</dt>
# <input name="hidNSValue" type="hidden" value="50001402,50001312,50001314,50001315,50012150,50001561"/>
# <!--common facet body -->
# <dd class="filter-box-body">
# <!-- body core -->
# <ul class="filter-box-list">
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001402">
# <input autocomplete="off" id="50001402" name="250" neg-n-value="50001402" type="checkbox">
# <span class="form-checkbox-title">EVGA</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(55)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001312">
# <input autocomplete="off" id="50001312" name="250" neg-n-value="50001312" type="checkbox">
# <span class="form-checkbox-title">MSI</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(51)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001314">
# <input autocomplete="off" id="50001314" name="250" neg-n-value="50001314" type="checkbox">
# <span class="form-checkbox-title">GIGABYTE</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(42)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001315">
# <input autocomplete="off" id="50001315" name="250" neg-n-value="50001315" type="checkbox">
# <span class="form-checkbox-title">ASUS</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(12)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50012150">
# <input autocomplete="off" id="50012150" name="250" neg-n-value="50012150" type="checkbox">
# <span class="form-checkbox-title">ZOTAC</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(18)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001561">
# <input autocomplete="off" id="50001561" name="250" neg-n-value="50001561" type="checkbox">
# <span class="form-checkbox-title">Sapphire Tech</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(16)</span>
# </li>
# <!-- range facet -->
# </ul>
# <!-- alone apply button-->
# <!-- show more area -->
# <input name="hidTempletUrlParms" type="hidden" value="Submit=ENE&amp;N=&amp;IsNodeId=1&amp;Description=graphics%20card&amp;Order=BESTMATCH"/>
# <!-- default hidden option-->
# <ul class="filter-box-list more">
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001028">
# <input autocomplete="off" id="50001028" name="250" neg-n-value="50001028" type="checkbox">
# <span class="form-checkbox-title">AMD</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(3)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50010418">
# <input autocomplete="off" id="50010418" name="250" neg-n-value="50010418" type="checkbox">
# <span class="form-checkbox-title">Lenovo</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(1)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001471">
# <input autocomplete="off" id="50001471" name="250" neg-n-value="50001471" type="checkbox">
# <span class="form-checkbox-title">PNY Technologies, Inc.</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(9)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001419">
# <input autocomplete="off" id="50001419" name="250" neg-n-value="50001419" type="checkbox">
# <span class="form-checkbox-title">PowerColor</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(11)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001180">
# <input autocomplete="off" id="50001180" name="250" neg-n-value="50001180" type="checkbox">
# <span class="form-checkbox-title">VisionTek</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(7)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="50001669">
# <input autocomplete="off" id="50001669" name="250" neg-n-value="50001669" type="checkbox">
# <span class="form-checkbox-title">XFX</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(9)</span>
# </li>
# <!-- range facet -->
# </ul>
# <!-- show more logic-->
# <div class="filter-box-bottom">
# <!-- show more area-->
# <span class="filter-box-more " id="" onclick="Biz.SearchPanel2016.Navigation.showMoreLessValues(this, 'Show More', 'Show Less')">
# <i class="fa filter-box-more-icon"></i>
# <span class="filter-box-more-text">Show More</span>
# </span>
# <!-- default loading img -->
# <span class="loader" style="display: none; padding: 0px">
# <img alt="Loading Icon" src="//images10.newegg.com/WebResource/Themes/2005/Nest/none.gif"/>
# </span>
# <!-- apply buttom -->
# <button class="btn btn-tool btn-mini filter-box-apply" id="fab_250" name="fabGroup" style="display: none;">Apply</button>
# <!-- popup-->
# </div>
# </dd>
# </dl>
# <dl class="filter-box has-menu is-active" id="facet4816">
# <!--common facet title -->
# <dt class="filter-box-title">Condition</dt>
# <input name="hidNSValue" type="hidden" value=""/>
# <!--common facet body -->
# <dd class="filter-box-body">
# <!-- body core -->
# <ul class="filter-box-list">
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4814">
# <input autocomplete="off" id="4814" name="4816" neg-n-value="4814" type="checkbox">
# <span class="form-checkbox-title">New</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(233)</span>
# </li>
# <!-- range facet -->
# </ul>
# <!-- alone apply button-->
# <div class="filter-box-bottom">
# <button class="btn btn-tool btn-mini filter-box-apply" id="fab_4816" name="fabGroup" style="display: none">Apply</button>
# </div>
# <!-- show more area -->
# </dd>
# </dl>
# <dl class="filter-box has-menu is-active" id="facet1000000000">
# <!--common facet title -->
# <dt class="filter-box-title">Seller</dt>
# <input name="hidNSValue" type="hidden" value=""/>
# <!--common facet body -->
# <dd class="filter-box-body">
# <!-- body core -->
# <ul class="filter-box-list">
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="8000">
# <input autocomplete="off" id="8000" name="1000000000" neg-n-value="8000" type="checkbox">
# <span class="form-checkbox-title">Newegg</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(211)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="1065548654">
# <input autocomplete="off" id="1065548654" name="1000000000" neg-n-value="1065548654" type="checkbox">
# <span class="form-checkbox-title">uShopMall</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(19)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="1065486574">
# <input autocomplete="off" id="1065486574" name="1000000000" neg-n-value="1065486574" type="checkbox">
# <span class="form-checkbox-title">Action Packaged Inc.</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(4)</span>
# </li>
# <!-- range facet -->
# </ul>
# <!-- alone apply button-->
# <div class="filter-box-bottom">
# <button class="btn btn-tool btn-mini filter-box-apply" id="fab_1000000000" name="fabGroup" style="display: none">Apply</button>
# </div>
# <!-- show more area -->
# </dd>
# </dl>
# <dl class="filter-box has-menu is-active" id="facet4800">
# <!--common facet title -->
# <dt class="filter-box-title">Useful Links</dt>
# <input name="hidNSValue" type="hidden" value=""/>
# <!--common facet body -->
# <dd class="filter-box-body">
# <!-- body core -->
# <ul class="filter-box-list">
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4802">
# <input autocomplete="off" id="4802" name="4800" neg-n-value="4802" type="checkbox">
# <span class="form-checkbox-title">Top Sellers</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(63)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4803">
# <input autocomplete="off" id="4803" name="4800" neg-n-value="4803" type="checkbox">
# <span class="form-checkbox-title">Discount Item</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(55)</span>
# </li>
# <!-- range facet -->
# <!-- common facet -->
# <li>
# <!-- checkbox and lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4804">
# <input autocomplete="off" id="4804" name="4800" neg-n-value="4804" type="checkbox">
# <span class="form-checkbox-title">New Arrival</span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(38)</span>
# </li>
# <!-- range facet -->
# </ul>
# <!-- alone apply button-->
# <div class="filter-box-bottom">
# <button class="btn btn-tool btn-mini filter-box-apply" id="fab_4800" name="fabGroup" style="display: none">Apply</button>
# </div>
# <!-- show more area -->
# </dd>
# </dl>
# <dl class="filter-box has-menu is-active" id="facet4110">
# <dt class="filter-box-title">Customer Ratings</dt>
# <dd class="filter-box-body">
# <ul class="filter-box-list">
# <li>
# <!-- egg style lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4115">
# <input autocomplete="off" id="4115" name="4110" neg-n-value="4115" title="Ratings" type="checkbox">
# <span class="form-checkbox-title">
# <i class="rating rating-5"></i>
# </span>
# </input></label>
# </div>
# <!-- item count-->
# <span class="filter-box-num">(85)</span>
# </li>
# <li>
# <!-- egg style lable -->
# <div class="filter-box-label">
# <label class="form-checkbox" for="4114">
# <input autocomplete="off" id="4114" name="4110" neg-n-value="4114" title="Ratings" type="checkbox">
# <span class="form-checkbox-title">
# <i class="rating rating-4"></i>
# </span>
# </input></label>
# </div>
# <!-- item count-->
# ...
# </li>
# <li class="footer-site-map-item"><a href="https://secure.newegg.com/Guest/EmailNotifications.aspx" id="emailNotificationFooterUrl" rel="nofollow" title="Email Notifications">
#                         Email Notifications
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://secure.newegg.com/NewMyAccount/AutoNotifyManagement.aspx" rel="nofollow" title="Auto Notifications">
#                         Auto Notifications
#                     </a></li>
# </ul>
# <ul class="nav-col">
# <li class="footer-site-map-title">
#                         Company Information
#                     </li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/AboutUs.aspx" title="About Newegg">
#                         About Newegg
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/Awards.aspx" title="Awards/Rankings">
#                         Awards/Rankings
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/OfficeHours.aspx" rel="nofollow" title="Hours and Locations">
#                         Hours and Locations
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Careers/TabIndex.aspx" rel="nofollow" title="Careers">
#                         Careers
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/Newsroom.aspx" title="Newsroom">
#                         Newsroom
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://blog.newegg.com/" target="_blank" title="Newegg Blog">
#                         Newegg Blog
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://kb.newegg.com/Article/Index/12/3?id=1331" title="Calif. Transparency in Supply Chains Act ">
#                             Calif. Transparency <br/>in Supply Chains Act
#                         </a></li>
# </ul>
# <ul class="nav-col">
# <li class="footer-site-map-title">
#                         Tools &amp; Resources
#                     </li>
# <li class="footer-site-map-item"><a href="//www.newegg.com/sellers/" rel="nofollow" title="Sell on Newegg Marketplace">
#                         Sell on Newegg Marketplace
#                     </a></li>
# <li class="footer-site-map-item"><a href="http://www.newegg.com/sbn/index.html" rel="nofollow" title="Shipped by Newegg">
#                             Shipped by Newegg
#                         </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/Affiliates.aspx" title="Become an Affiliate">
#                         Become an Affiliate
#                     </a></li>
# <li class="footer-site-map-item"><a href="//promotions.newegg.com/nepro/12-0435/index.html" title="Become a Newegg Vendor">
#                         Become a Newegg Vendor
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Info/SiteMap.aspx" title="Site Map">
#                         Site Map
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/ProductSort/BrandList.aspx?Depa=0" rel="nofollow" title="Shop by Brand">
#                             Shop by Brand
#                         </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Feedback/Reviews.aspx" rel="nofollow" title="Product Review">
#                         Product Review
#                     </a></li>
# <li class="footer-site-map-item"><a href="//www.newegg.tv/" rel="nofollow" title="Video Center">
#                         Video Center
#                     </a></li>
# <li class="footer-site-map-item"><a href="https://www.newegg.com/global/in/Special/Rebate.aspx?name=Rebate-Center" title="Rebates">
#                         Rebates
#                     </a></li>
# <li class="footer-site-map-item"><a href="//promotions.newegg.com/nepro/16-2146/index.html" rel="nofollow" title="Trade-In Your Items">
#                             Trade-In Your Items
#                         </a></li>
# <li class="footer-site-map-item"><a href="http://www.newegg.com/mobile?name=Mobile-Apps" rel="nofollow" title="Mobile Apps">
#                         Mobile Apps
#                     </a></li>
# </ul>
# </div>
# </nav>
# <nav class="shop-region">
# <div class="page-footer-inner">
# <!--<span class="shop-region-title">
#                         Affiliated Sites:
#                     </span>-->
# <ul class="shop-region-list">
# <li>
# <a href="https://promotions.newegg.com/international/global/index.html" rel="nofollow" target="_blank" title="Newegg Global(new window)">
#                                     Newegg Global
#                                     <br>
# <span class="shop-region-list-note">
#                                         International Shopping
#                                     </span>
# </br></a>
# </li>
# <li>
# <a href="//www.neweggbusiness.com/" rel="nofollow" target="_blank" title="Newegg Retail Site(new window)">
#                                      NeweggBusiness
#                                     <br>
# <span class="shop-region-list-note">
#                                         For Business Needs
#                                     </span>
# </br></a>
# </li>
# <li>
# <a href="https://community.newegg.com/" rel="nofollow" target="_blank" title="Newegg Community(new window)">
#                                     Newegg Community
#                                     <br>
# <span class="shop-region-list-note">
#                                         Newegg Community
#                                     </span>
# </br></a>
# </li>
# <li>
# <a href="http://www.gamecrate.com/" rel="nofollow" target="_blank" title="Newegg GameCrate(new window)">
#                                     Newegg GameCrate
#                                     <br>
# <span class="shop-region-list-note">
#                                         Gaming and Hardware News
#                                     </span>
# </br></a>
# </li>
# </ul>
# <ul class="social-follow-list">
# <li class="social-follow-item">
# <a class="fa fa-facebook social-follow-item-icon" href="http://www.facebook.com/Newegg" target="_blank"><span style="display: none">Facebook</span></a>
# </li>
# <li class="social-follow-item">
# <a class="fa fa-twitter social-follow-item-icon" href="http://twitter.com/Newegg" target="_blank"><span style="display: none">Twitter</span></a>
# </li>
# <li class="social-follow-item">
# <a class="fa fa-instagram social-follow-item-icon" href="http://instagram.com/newegg/" target="_blank"><span style="display: none">Instagram</span></a>
# </li>
# <li class="social-follow-item">
# <a class="fa fa-google-plus social-follow-item-icon" href="https://plus.google.com/+Newegg" target="_blank"><span style="display: none">Google</span></a>
# </li>
# <li class="social-follow-item">
# <a class="fa fa-pinterest social-follow-item-icon" href="http://pinterest.com/newegg/" target="_blank"><span style="display: none">Pinterest</span></a>
# </li>
# <li class="social-follow-item">
# <a class="fa fa-youtube-play social-follow-item-icon" href="http://www.youtube.com/neweggtv" target="_blank"><span style="display: none">YouTube</span></a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="footer-awards" id="footerAwards">
# <script type="text/javascript">
#                 usingNamespace("Biz.Footer")["Config"] = {
#                     veriSignUrl: "https://trustsealinfo.websecurity.norton.com/splash?form_file=fdf/splash.fdf&dn=SECURE.NEWEGG.COM&lang=en"
#                 };
#             </script>
# <a class="noline" href="javascript:Biz.Common.VeriSign.open();">
# <img alt="VeriSign" src="//images10.newegg.com/WebResource/Themes/2005/Nest/awards_04.gif" style="border: 0;">
# </img></a>
# <a class="noline" href="https://www.bbb.org/losangelessiliconvalley/business-reviews/computers-supplies-and-parts/newegg-in-whittier-ca-13146135" title="Click for the BBB Business Review of this Computers - Supplies &amp; Parts in Whittier CA">
# <img alt="Click for the BBB Business Review of this Computers - Supplies &amp; Parts in Whittier CA" src="//images10.newegg.com/WebResource/Themes/2005/Nest/blue-seal-newegginc.png" style="border: 0;"/>
# </a>
# <script src="https://sealserver.trustwave.com/seal.js?code=337bdba159684b989be28d750101ed87" type="text/javascript"></script><a class="noline" href="//www.newegg.com/Info/Awards.aspx" rel="nofollow">
# <img alt="Inc500" src="//images10.newegg.com/WebResource/Themes/2005/Nest/inc500.gif" style="border: 0;"/></a><span id="gtrust_badges"></span>
# </div>
# </footer>
# <!--footer area end-->
# <div class="footer-disclaimer">
# <a href="https://kb.newegg.com/Article/Index/12/3?id=1165" rel="nofollow">
#                         Policy &amp; Agreement
#                     </a>| <a href="https://kb.newegg.com/Article/Index/12/3?id=1166" rel="nofollow">
#                         Privacy Policy
#                     </a>
#
#          © 2000-2017 Newegg International Inc.
# 		 <span id="ieFontCheck" style="width:0px;">A</span>ll rights reserved.
#     </div>
# <div class="v655" id="overlay" style="display: none;">
# </div>
# <div class="v655" id="modal" style="display: none;">
# <span class="atnIcon icnInfo">
# <img alt="More Information" src="//images10.newegg.com/WebResource/Themes/2005/Nest/none.gif"/></span> <a class="atnIcon icnClose" href="javascript:void();" onclick="display.closeModal();">
# <img alt="close" src="//images10.newegg.com/WebResource/Themes/2005/Nest/none.gif"/>Close</a>
# <div class="content">
# </div>
# <img alt="loading" src="//images10.newegg.com/WebResource/Themes/2005/Nest/loading16.gif" style="display: none;"/>
# </div>
# <div class="v660">
# <div id="modalCommon" style="display: none;">
# <span class="atnIcon icnInfoNew" id="AlarmPanelNewCommon">
# <img alt="" class="iconNew" src="//images10.newegg.com/WebResource/Themes/2005/Nest/none.gif"/>
# <span class="title"></span></span><a class="atnIcon icnCloseNew" href="javascript:void(0);" onclick="Biz.Common.CommonPop.closePopup();">
# <img alt="close window" src="//images10.newegg.com/WebResource/Themes/2005/Nest/none.gif"/></a>
# <div class="content popUpLink" id="modalContent">
# </div>
# <div class="footer">
# <a href="javascript:void(0);" onclick="Biz.Common.CommonPop.closePopup();">
#                         close window
#                     </a>
# </div>
# </div>
# </div>
# <img alt="" height="0" src="//images10.newegg.com/WebResource/Themes/2005/Nest/Gomeznone63.gif" title="" width="0"/>
# <span style="display: none;">
#     If the Adobe Reader does not appear when you click on a link for a PDF file, you can <a href="https://www.adobe.com/products/acrobat/readstep.html">download Adobe Reader from the Adobe web site</a>.
# </span>
# <script type="text/javascript">
#     jQuery(document).ready(function () { Biz.Common.PageFooter.setLink(); });
# </script>
# <!-- end: footer -->
# <script language="javascript">      function storeSREDID() {var thirtyDays=(60*60*1000*24)*30;var vals=document.location.search;start=vals.indexOf("SREDID=");if (start!=-1) {var end=vals.indexOf("&", start);if (end==-1){ end=vals.length; }var date=new Date();date.setTime(date.getTime()+ thirtyDays);document.cookie=vals.substring(start,end)+"; expires="+date.toGMTString()+"; path=/";}}function getSREDID(){var n="SREDID=";var cookies=document.cookie;var start=cookies.indexOf(n);if (start==-1){ return null; }start += n.length ;var end=cookies.indexOf(";", start);if (end==-1){ end=cookies.length; }return cookies.substring(start, end);}storeSREDID();      </script>
# <iframe src="https://www.newegg.com/global/in/Common/ThirdParty/IFrame3rdPartyCodeTotal.aspx?ThirdPartyCodeIDList=55&amp;page=ProductList&amp;cretiopagelistitemnumber=%27N82E16814202279%27%2c%27N82E16814137056%27%2c%27N82E16814137093%27&amp;cretiosearchkeywords=graphics%20card" style="border:0;width:0;height:0;" title="ForThirdParty">iframe for third party code</iframe>
# <!-- BEGIN SiteCatalyst --><script type="text/javascript">jQuery(document).ready(function () {var parms=[];var re1 = new RegExp('(\\?|&)?icid=([^&]*)');jQuery('a').each(function (n) {var m_name = re1.exec(jQuery(this).attr('href'));if (m_name!=null) { parms.push(m_name[2]);}});if (parms.length>0) {Biz.Common.SiteCatalyst.sendForOnClick({ 'prop21': parms.join(",")}, 'banner impression');}})</script><script type="text/javascript">var scp=typeof(scp)=='undefined'?{}:scp;scp.cmPageName="search results\x3a successful";scp.serverName="E4WEB13";scp.pageType="Targetting;Search";scp.refinementType="Page Viewed,Sort By,View Count";scp.refinementValue="Page Viewed\x3a1,Sort By\x3aBestMatch,View Count\x3a36";scp.engine="dominated";scp.searchKeyWord="graphics card";scp.searchResult="226";scp.searchType="successful";scp.pageNickName="ProductList";Biz.Common.SiteCatalyst.send(scp);</script><!-- END SiteCatalyst -->
# <!-- BEGIN: Google Trusted Store -->
# <script type="text/javascript">
# 					  var gts = gts || [];
#
# 					  gts.push(["id", "69025"]);
# 					  gts.push(["google_base_offer_id", ""]);
# 					  gts.push(["google_base_subaccount_id","8277688"]);
# 					  gts.push(["google_base_country","US"]);
# 					  gts.push(["google_base_language","en"]);
# 	          gts.push(["gtsContainer","gtrust_badges"]);
#
# 					  (function() {
# 						var scheme = (("https:" == document.location.protocol) ? "https://" : "http://");
# 						var gts = document.createElement("script");
# 						gts.type = "text/javascript";
# 						gts.async = true;
# 						gts.src = scheme + "www.googlecommerce.com/trustedstores/gtmp_compiled.js";
# 						var s = document.getElementsByTagName("script")[0];
# 						s.parentNode.insertBefore(gts, s);
# 					  })();
# 					</script>
# <!-- END: Google Trusted Store -->
# <script type="text/javascript">
#       var utag_data = {
#       page_breadcrumb:'Home &gt; graphics card',
#             search_result_type:'successful',
#             page_number:'1',
#             organic_skus:'N82E16814202279|N82E16814137056|N82E16814137093|N82E16814133724|N82E16814500411|N82E16814125402|N82E16814125675|N82E16814487365|9SIA6V660S5499|9SIA6V664D3174|N82E16814126204|N82E16814121880|N82E16814125954|N82E16814125997|N82E16814137148|N82E16814130586|N82E16814130602|N82E16814125875|N82E16814125871|N82E16814127763|N82E16814125987|N82E16814487220|N82E16814487321|0E6-009A-001X1|N82E16814133634|N82E16814500366|N82E16814500420|N82E16814150795|N82E16814125953|N82E16814126114|N82E16814137226|N82E16814137090|N82E16814137159|N82E16814500412|N82E16814127906|N82E16814487265',
#             product_organic_skus:['N82E16814202279','N82E16814137056','N82E16814137093'],
#             search_results:226,
#             search_keyword:'graphics card',
#             page_type:'Search',
#             page_sort:jQuery('#Order_top option:selected').text(),
#             page_size:Biz.ProductList.Config.pagesize,
#             site_region:'IND',
#             site_currency:'INR',
#             page_name:'ProductList',
#             search_scope:jQuery('#haQuickSearchStore option:selected').text(),
#             user_nvtc:Web.StateManager.Cookies.get(Web.StateManager.Cookies.Name.NVTC),
#             user_name:Web.StateManager.Cookies.get(Web.StateManager.Cookies.Name.LOGIN,'LOGINID6'),
#             third_party_render:['8fe4252844a78259b3a46bc360ea11f25f9714df','65531e14b4d9b9a223cc3bfcb65ce7b5f356011d','2a5e772a0f941c862180037f8a5c118c7abf2f7d']
#
#       };
#       </script>
# <script type="text/javascript">
#       (function(a,b,c,d){
#           a='//tags.tiqcdn.com/utag/newegg/newegg.com/prod/utag.js';
#           b=document;
#           c='script';
#           d=b.createElement(c);
#           d.src=a;
#           d.type='text/java'+c;
#           d.async=true;
#           a=b.getElementsByTagName(c)[0];
#           a.parentNode.insertBefore(d,a)
#       })();
#       </script>
# <script type="text/javascript">var store_data={storeTypeInt:'-1',
# };</script>
# <script type="text/javascript">_satellite.pageBottom();</script>
# </body>
# </html>
