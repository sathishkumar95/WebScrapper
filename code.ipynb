# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup 

my_url = 'https://www.newegg.com/global/in/Product/ProductList.aspx?Submit=ENE&DEPA=0&Order=BESTMATCH&Description=graphics+card&N=-1&isNodeId=1'

uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

#html parsing

page_soup = soup(page_html,"html.parser")

#grabs each product

containers = page_soup.findAll("div",{"class":"item-container"})

#creating and writing into a file

filename = "product.csv"

f = open(filename,"w")

headers = "brand, product_name, shipping \n"

f.write(headers)

for container in containers:
	brand = container.div.div.a.img["title"]

	title_container = container.findAll("a",{"class":"item-title"})
	product_name = title_container[0].text

	shipping_container = container.findAll("li",{"class":"price-ship"})
	shipping = shipping_container[0].text.strip()

	print("brand : "+brand)
	print("product_name : "+product_name)
	print("shipping : "+shipping)
	f.write(brand+ "," +product_name.replace(",","|")+ "," +shipping+ "\n")

f.close()
# Out:
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1080 Ti AMP Extreme Core 11GB GDDR5X 352-bit Gaming Graphics Card VR Ready 16+2 Power Phase Freeze Fan Stop IceStorm Cooling Spectra Lighting ZT-P10810F-10P
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1080 Ti AMP Edition 11GB GDDR5X 352-bit Gaming Graphics Card VR Ready 16+2 Power Phase Freeze Fan Stop IceStorm Cooling Spectra Lighting ZT-P10810D-10P
# shipping :
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 950 Graphic Card - 1.02 GHz Core - 1.19 GHz Boost Clock - 2 GB GDDR5 - PCI Express 3.0 x16
# shipping :
# brand : ASUS
# product_name : ASUS ROG Strix Radeon RX 580 T8G Gaming Top OC Edition GDDR5 DP HDMI DVI VR Ready AMD Graphics Card (ROG-STRIX-RX580-T8G-GAMING)
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1080 Ti AMP Extreme 11GB GDDR5X 352-bit Gaming Graphics Card VR Ready 16+2 Power Phase Freeze Fan Stop IceStorm Cooling Spectra Lighting ZT-P10810C-10P
# shipping :
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 750 Ti GDDR5 1GB OC Graphic Card REV 2.0
# shipping :
# brand : Lenovo
# product_name : Lenovo 4X60M28228 Nvidia Quadro M2000 - Graphics Card - Quadro M2000 - 4 Gb - 4 X Displayport - For Thinkstation P410, P510
# shipping :
# brand : ASUS
# product_name : Asus R5230-SL-2GD3-L Radeon R5 230 Graphic Card - 650 MHz Core - 2 GB DDR3 SDRAM - PCI Express 2.1 - Low-profile
# shipping :
# brand : VisionTek
# product_name : VisionTek Radeon 5450 SFF 1GB DDR3 (DVI-I, DP, VGA) Graphics Card - 900320
# shipping :
# brand : ASUS
# product_name : ASUS Radeon RX 550 4G GDDR5 DP HDMI DVI AMD Graphics Card (RX550-4G)
# shipping :
# brand : ASUS
# product_name : ASUS Radeon RX 550 2G GDDR5 DP HDMI DVI AMD Graphics Card (RX550-2G)
# shipping :
# brand : PowerColor
# product_name : PowerColor AXR7 240 2GBK3-HLE AMD Radeon R7 240 2GB Graphics Card - OEM
# shipping :
# brand : GIGABYTE
# product_name : Gigabyte Ultra Durable 2 GV-R523D3-1GL (rev. 2.0) Radeon R5 230 Graphic Card - 625 MHz Core - 1 GB DDR3 SDRAM - PCI Express 2.0 - Low-profile - Single Slot Space Required
# shipping :
# brand : ASUS
# product_name : ASUS ROG Strix Radeon RX 570 O4G Gaming OC Edition GDDR5 DP HDMI DVI VR Ready AMD Graphics Card (ROG-STRIX-RX570-O4G-GAMING)
# shipping :
# brand : ASUS
# product_name : ASUS Radeon RX 560 2GB OC Edition GDDR5 DP HDMI DVI AMD Graphics Card (RX560-O2G)
# shipping :
# brand : PNY Technologies, Inc.
# product_name : PNY GeForce GTX 1080 Founders Edition 8GB GDDR5X PCI Express 3.0 Graphics Card VCGGTX10808PB-CG
# shipping :
# brand : PowerColor
# product_name : PowerColor RED DEVIL Radeon RX 580 DirectX 12 AXRX 580 8GBD5-3DH/OC 8GB 256-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Video Card
# shipping :
# brand : MSI
# product_name : MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 4G OC 4GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready CrossFireX Support ATX Video Card
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1080 Ti SC2 GAMING, 11G-P4-6593-KR, 11GB GDDR5X, iCX Technology - 9 Thermal Sensors & RGB LED G/P/M
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1080 Ti FTW3 GAMING, 11G-P4-6696-KR, 11GB GDDR5X, iCX Technology - 9 Thermal Sensors & RGB LED G/P/M
# shipping :
# brand : Sapphire Tech
# product_name : Sapphire Radeon NITRO+ RX 570 4GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)
# shipping :
# brand : MSI
# product_name : MSI GeForce GTX 1060 DirectX 12 GTX 1060 3GT OC 3GB 192-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready ATX Video Card
# shipping :
# brand : Sapphire Tech
# product_name : Sapphire Radeon NITRO+ RX 580 4GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)
# shipping :
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 HYBRID GAMING, 08G-P4-6178-KR, 8GB GDDR5, LED, All-In-One Watercooling, DX12 OSD Support (PXOC)
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1070 Mini, ZT-P10700G-10M, 8GB GDDR5
# shipping :
# brand : VisionTek
# product_name : VisionTek Radeon RX 560 DirectX 12 900962 2GB 128-Bit GDDR5 PCI Express x16 Video Card
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1080 SC GAMING ACX 3.0, 08G-P4-6183-KR, 8GB GDDR5X, LED, DX12 OSD Support (PXOC)
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1080 FTW DT GAMING ACX 3.0, 8GB GDDR5X, RGB LED, 10CM FAN, 10 Power Phases, DX12, 08G-P4-6284-KR
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1060 AMP!, ZT-P10600B-10M, 6GB GDDR5 Super Compact Dual-Fan IceStorm Cooling FREEZE Fan Stop
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1060 Mini, ZT-P10600A-10L, 6GB GDDR5 Super Compact
# shipping :
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1060 Mini, ZT-P10610A-10L, 3GB GDDR5 Super Compact
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 FTW2 GAMING iCX, 08G-P4-6676-KR, 8GB GDDR5, RGB LED, 9 Thermal Sensors, Asynchronous Fan Control, Thermal Display LED System, Optimized Airflow Fin Design
# shipping :
# brand : EVGA
# product_name : EVGA GeForce GTX 1080 SC2 GAMING iCX, 08G-P4-6583-KR, 8GB GDDR5X, 9 Thermal Sensors, Asynchronous Fan Control, Thermal Display LED System, Optimized Airflow Fin Design, Die Cast/Form Fitted Baseplate
# shipping :
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060WF2OC-6GD 6GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060G1 GAMING-3GD 2.0 3GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping :
